# %%
from __future__ import print_function
import sys
import os
import cv2
from matplotlib import pyplot as plt
import numpy as np

from local_config import CURRENT_DIR
sys.path.append(os.path.join(CURRENT_DIR, ".."))
try:
    from config import Config
except:
    print("cannot load modules")
    sys.exit(0)

# %%
from data_loader import LipDataset
dt_config = Config()
dataset = LipDataset(data_path=dt_config.DATA_PATH, phase="train")

# %%
plt.figure(figsize=(15,15))
plt.imshow(cv2.cvtColor(dataset.legend, cv2.COLOR_BGR2RGB))
cv2.imwrite("lip_color_chart.png", dataset.legend)
# Out:
# True

# %%
print(len(dataset))
# Out:
# 30462

# %%
sample_overlay_img = dataset.get_overlay_image(idx=2700)

plt.figure(figsize=(15,15))
plt.imshow(cv2.cvtColor(sample_overlay_img, cv2.COLOR_BGR2RGB))

# %%
img, gt = dataset[7]

# %%
np.unique(gt)
# Out:
# array([ 0,  2,  5,  9, 13, 14, 15, 16, 17, 18, 19], dtype=uint8)
